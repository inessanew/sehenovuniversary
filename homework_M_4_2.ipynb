# %% [markdown]
# Задание 1

# %%
love = input()
print ("Приветствую,", love)
# Out:
# Приветствую, Ines

# %%
temp = float(input("t"))
if 36 <= temp <= 37:
    print("norm")
else:
    print("not norm")
# Out:
# norm

# %%
grade = int(input())
print ("Ваша оценка - ", end="  ")
if grade >= 90:
    print (5)
else:
    if grade >= 75:
        print (4)
    else:
        if grade >= 60:
            print(3)
        else:
            print(2)
# Out:
# Ваша оценка -   5

# %%
grade = int(input())
print ("Ваша оценка - ", end="  ")
if grade >= 90:
    print (5)
elif grade >= 75:
    print (4)
elif grade >= 60:
    print(3)
else:
    print(2)
# Out:
# Ваша оценка -   4

# %%
for i in range (3) :
    print("я молодец")
# Out:
# я молодец
# я молодец
# я молодец

# %%
for hour in range (2) :
    for min in range (3) :
        print(hour, ":", min)
# Out:
# 0 : 0
# 0 : 1
# 0 : 2
# 1 : 0
# 1 : 1
# 1 : 2

# %%
#theme 16
nm = input
nmf = input
nm = "Антон"
nmf = "Иванов"
print ("Привет,", nm + " "+ nmf+"! " "Вы только что начали изучать Python!")
# Out:
# Привет, Антон Иванов! Вы только что начали изучать Python!

# %%
#theme 17
part_1 = input
part_2 = input
part_3 = input
part_1, part_2, part_3 = '"Каждый в этой стране должен', 'научиться программировать,', 'потому что это учит думать."'
print(part_1+" "+ part_2 +" "+ part_3)
# Out:
# "Каждый в этой стране должен научиться программировать, потому что это учит думать."

# %%
#
actual = int(input("Фактическое выполнение:  "))
plan = int(input("Плановая задача:  "))
print (plan <= actual)
# Out:
# True

# %%
#theme18
bag = (input)
bag = 999
print( bag > 1000)
# Out:
# False

# %%
#theme18
bag = int(input())
print( bag > 1000)
# Out:
# True

# %%
#them19
ages = int(input('Введите ваш возраст:  '))
print( ages >= 18)
# Out:
# True

# %%
#them 20
V1 = 50
V2 = 70
S = 500
t = S/(V1+V2)
print(t)
# Out:
# 4.166666666666667

# %%
#them21
a = input 
b = input
a = 443 #Длина первого катета
b = 390 #Длина второго катета
S = a*b/2
print(S)
# Out:
# 86385.0

# %%
#them 22
tF = float(input()) #450.55
tC = 5/9*(tF-32)
print(tC)
# Out:
# 232.5277777777778

# %%
#them23
revenue = float(input()) #438746,78
courier_name = input('Имя курьера - ')
bonus = int(revenue/100)
print('Курьер', courier_name, 'получит бонус', bonus )
# Out:
# Курьер Антон получит бонус 4387
